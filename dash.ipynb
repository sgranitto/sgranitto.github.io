# %%
pip install dash==1.11.0
# Out:
# Requirement already satisfied: dash==1.11.0 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (1.11.0)
# Requirement already satisfied: dash-html-components==1.0.3 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from dash==1.11.0) (1.0.3)
# Requirement already satisfied: Flask>=1.0.2 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from dash==1.11.0) (1.1.1)
# Requirement already satisfied: flask-compress in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from dash==1.11.0) (1.4.0)
# Requirement already satisfied: plotly in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from dash==1.11.0) (4.5.2)
# Requirement already satisfied: dash-renderer==1.4.0 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from dash==1.11.0) (1.4.0)
# Requirement already satisfied: dash-table==4.6.2 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from dash==1.11.0) (4.6.2)
# Requirement already satisfied: future in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from dash==1.11.0) (0.17.1)
# Requirement already satisfied: dash-core-components==1.9.1 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from dash==1.11.0) (1.9.1)
# Requirement already satisfied: click>=5.1 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from Flask>=1.0.2->dash==1.11.0) (7.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from Flask>=1.0.2->dash==1.11.0) (2.10.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from Flask>=1.0.2->dash==1.11.0) (0.16.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from Flask>=1.0.2->dash==1.11.0) (1.1.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from plotly->dash==1.11.0) (1.3.3)
# Requirement already satisfied: six in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from plotly->dash==1.11.0) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->dash==1.11.0) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash_core_components
print(dash_core_components.__version__)
# Out:
# 1.9.0

# %%
pip install dash-renderer==1.4.0
# Out:
# Requirement already satisfied: dash-renderer==1.4.0 in c:\users\sgranitto\appdata\local\continuum\anaconda3\lib\site-packages (1.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

# Uses an External Stylesheet
# Use a css file from your GitHub Pages site 
external_stylesheets = ['https://usfmumaanalyticsteam.github.io/learn.css']

# Creates the app to instantiate the content for the Dashboard and use the external_stylesheets
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Use a csv dataset from a repository in your GitHub account. Use the Raw URL to expose the data to the Python dataframe
df = pd.read_csv('https://raw.githubusercontent.com/sgranitto/sgranitto.github.io/master/data.csv')


# Custom function used to generate a data table from a dataframe
def generate_table(dataframe, max_rows=16):
    return html.Table([
        html.Thead(
            html.Tr([html.Th(col) for col in dataframe.columns])
        ),
        html.Tbody([
            html.Tr([
                html.Td(dataframe.iloc[i][col]) for col in dataframe.columns
            ]) for i in range(min(len(dataframe), max_rows))
        ])
    ])


# Add content to the app layout
# Begin all content DIV
app.layout=html.Div([
    # Add your HTML tags to the content - notice a comma is added between HTML elements
    html.H1('Data Visualization for Story Telling'),
    html.Div([
        html.P('Average Closing Price of US Stock'),
    ]),
    # Begin of DIV surrounding both Tables
    html.Div([
    # Begin of First Table
    html.Table(style={'width':'100%'},
               # Begin of Table children
               children=[
                   #######################################################################
                   # Begin of First Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Th
                         
                         html.Th(style={'width':'30%'},
                             # Begin Th children
                             children=[
                                 html.H3('Average Closing Price of US Stock')
                             # End of Th children   
                             ]
                         
                         # End of Th - Notice a comma is placed here to separate the next Th
                         ),
                         # Begin of Th
                         html.Th(style={'width':'70%'},
                             # Begin of Th children
                             children=[
                                 html.H3('Average Closing Price of US Stock')
                             # End of Th children    
                             ]
                         
                         # End of Th
                         )
                         
                     # End of Tr children    
                     ]
                 # End of First Tr - Notice a comma is placed here to separate the next Tr
                 ),
                 #########################################################################
                 # Begin of Second Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Td
                         html.Td(
                             # Begin Td children
                             children=[
                                    # Display bar graph
                                    dcc.Graph(
                                    id='example-graph',
                                    figure={
                                        'data': [
                                            {'x': [1, 2, 3], 'y': [4, 1, 2], 'type': 'bar', 'Time': 'Stock Daily Close - Unadjusted Prices USA OTC OTC Bulletin Board Markets IWSY Imageware Systems Inc - - USD
'},
                                        ],
                                        'layout': {
                                            'title': 'Average Closing Price of US Stock'
                                        }
                                    }
                                # End of Chart 1
                                )
                              # End of Td children   
                             ]
                         
                         # End of Td - Notice a comma is placed here to separate the next Th
                         ),
                         # Being of Td
                         html.Td(
                             # Begin of Td children
                             children=[
                                 # Display plot graph use data from dataframe df
                                 dcc.Graph(
                                    id='life-exp-vs-gdp',
                                figure={
                                    'data': [
                                        dict(
                                            x=df[df['continent'] == i]['gdp per capita'],
                                            y=df[df['continent'] == i]['life expectancy'],
                                            text=df[df['continent'] == i]['country'],
                                            mode='markers',
                                            opacity=0.7,
                                            marker={
                                                'size': 15,
                                                'line': {'width': 0.5, 'color': 'white'}
                                            },
                                            name=i
                                        ) for i in df.continent.unique()
                                    ],
                                    'layout': dict(
                                        xaxis={'type': 'log', 'title': 'GDP Per Capita'},
                                        yaxis={'title': 'Life Expectancy'},
                                        margin={'l': 40, 'b': 40, 't': 10, 'r': 10},
                                        legend={'x': 0, 'y': 1},
                                        hovermode='closest'
                                    ), 'layout': {
                                            'title': 'GDP by Continent'}
                                    # End of 2nd Inner DIV
                                    })
                           
                             # End of Td children    
                             ]
                         # End of Td
                         )
                     # End of Tr children    
                     ]
                 # End of Tr
                 )     
                #########################################################################                   
               #End of Table Children    
               ]
              # End of First Table - Notice a comma is placed here to separate the next Table
              ),
    
    #########################################################################################   
    # Begin of Second Table
    html.Table(style={'width':'100%'},
               children=[
                 #######################################################################
                 # Begin First Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Th
                         html.Th(style={'width':'30%'},
                             # Begin Th children
                             children=[
                                 html.H3('2019 Impact of Exports on US GDP')
                             # End of Th children   
                             ]
                         
                         # End of Th - Notice a comma is placed here to separate the next Th
                         ),
                         #Begin of Th
                         html.Th(style={'width':'10%'},
                             # Begin of Th children
                                 children=[
                                 # Nothing to display here, just a place holder in the column
                                 html.H2('')
                                 # End of Th children    
                                 ]
                             # End of Th - Notice a comma is placed here to separate the next Th
                         ),
                         # Begin of Th
                         html.Th(style={'width':'70%'},
                             # Begin of Th children
                             children=[        
                                    html.H3('Top 15 US States and their Domestic Exports')
                                                               
                             # End of Th children    
                             ]
                         # End of Th
                         )
                     # End of Tr children    
                     ]
                 # End of First Tr
                 ),
                   
                ######################################################################
                # Begin of Second Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Td
                         html.Td(
                             # Begin Td children
                             children=[
                                    # Display a simple line graph
                                    dcc.Graph(
                                        id='g1', 
                                        figure={'data': [{'y': [1, 2, 3]}], 
                                                'layout': {'title': 'Impact on US GDP'}})
                             # End of Td children   
                             ]
                         
                         # End of Td - Notice a comma is placed here to separate the next Th
                         ),
                         # Begin of Td
                         html.Td(style={'border':'1px solid black'},
                             # Begin of Td children
                             children=[
                                 # Display a large and important measure
                                 html.H2('Domestic'),
                                 html.H2('Exports:'),
                                 html.H2('80%')
                             # End of Td children    
                             ]
                         # End of Td
                         ),
                         
                         # Begin of Td
                         html.Td(
                             # Begin of Td children
                             children=[
                                    # Execute custom generate_table function and display data
                                    # Use data from dataframe df2
                                    generate_table(df2)
                             # End of Td children    
                             ]
                         # End of Td
                         )
                     # End of Tr children    
                     ]
                 # End of Second Tr
                 )     
               
               #######################################################################
               #End of Table Children    
               ]
              #########################################################################################
              # End of Second Table - Notice a comma is placed here to separate the next Content
              ),
    # End of DIV surrounding both Tables
    ]),
               
# End of all content DIV
])

# Run the app on the web server
if __name__ == '__main__':
    # Set debug to False. Some configurations are not setup for Debug
    app.run_server(debug=False)
# Out:
#   File "<ipython-input-10-11415969eaee>", line 90
#     {'x': [1, 2, 3], 'y': [4, 1, 2], 'type': 'bar', 'Time': 'Stock Daily Close - Unadjusted Prices USA OTC OTC Bulletin Board Markets IWSY Imageware Systems Inc - - USD
#                                                                                                                                                                         ^
# SyntaxError: EOL while scanning string literal
